# %%
import pandas as pd

DATA_URL = '../data/deaths_raw.csv'

# %%
## Read data into a pandas dataframe
df = pd.read_csv(DATA_URL)
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/24/20  3/25/20  3/26/20  3/27/20  \
# 0        0        0        0  ...        1        2        4        4
# 1        0        0        0  ...        5        5        6        8
# 2        0        0        0  ...       19       21       25       26
# 3        0        0        0  ...        1        1        3        3
# 4        0        0        0  ...        0        0        0        0
#
#    3/28/20  3/29/20  3/30/20  3/31/20  4/1/20  4/2/20
# 0        4        4        4        4       4       6
# 1       10       10       11       15      15      16
# 2       29       31       35       44      58      86
# 3        3        6        8       12      14      15
# 4        0        2        2        2       2       2
#
# [5 rows x 76 columns]

# %%
df.drop(['Province/State', 'Lat', 'Long'], axis=1,inplace=True)
df.set_index('Country/Region', inplace=True)

# %%
df_country = df.groupby(['Country/Region']).sum()

df_country.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  3/24/20  3/25/20  3/26/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...        1        2        4
# Albania               0        0        0  ...        5        5        6
# Algeria               0        0        0  ...       19       21       25
# Andorra               0        0        0  ...        1        1        3
# Angola                0        0        0  ...        0        0        0
#
#                 3/27/20  3/28/20  3/29/20  3/30/20  3/31/20  4/1/20  4/2/20
# Country/Region
# Afghanistan           4        4        4        4        4       4       6
# Albania               8       10       10       11       15      15      16
# Algeria              26       29       31       35       44      58      86
# Andorra               3        3        6        8       12      14      15
# Angola                0        0        2        2        2       2       2
#
# [5 rows x 72 columns]

# %%
df_country_day = df_country.unstack()
df_country_day
# Out:
#          Country/Region
# 1/22/20  Afghanistan           0
#          Albania               0
#          Algeria               0
#          Andorra               0
#          Angola                0
#                               ..
# 4/2/20   Venezuela             5
#          Vietnam               0
#          West Bank and Gaza    1
#          Zambia                1
#          Zimbabwe              1
# Length: 13032, dtype: int64

# %%
df_change = df_country_day.to_frame(name='deaths')
df_change['yesterdays_deaths'] = df_change.groupby(['Country/Region'])['deaths'].shift(1)
df_change['change_in_deaths'] = df_change['deaths'] - df_change['yesterdays_deaths']
df_change
# Out:
#                             deaths  yesterdays_deaths  change_in_deaths
#         Country/Region
# 1/22/20 Afghanistan              0                NaN               NaN
#         Albania                  0                NaN               NaN
#         Algeria                  0                NaN               NaN
#         Andorra                  0                NaN               NaN
#         Angola                   0                NaN               NaN
# ...                            ...                ...               ...
# 4/2/20  Venezuela                5                3.0               2.0
#         Vietnam                  0                0.0               0.0
#         West Bank and Gaza       1                1.0               0.0
#         Zambia                   1                0.0               1.0
#         Zimbabwe                 1                1.0               0.0
#
# [13032 rows x 3 columns]

# %%
df_change.to_csv('../data/df_death_changes.csv')

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:changeme@postgres:5432/covid', isolation_level='AUTOCOMMIT')
conn = engine.connect()

# conn.execute('create database covid;')

# %%
# Insert data into postgresSQL - a bit slow - there are better ways here
df_country_day.to_sql('total_deaths', engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2078457cd4ff> in <module>
#       1 # Insert data into postgresSQL - a bit slow - there are better ways here
# ----> 2 df_country_day.to_sql('total_deaths', engine)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1317             dtype=dtype,
#    1318         )
# -> 1319         table.create()
#    1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/sql.py in create(self)
#     642             if self.if_exists == "fail":
#     643                 raise ValueError(
# --> 644                     "Table '{name}' already exists.".format(name=self.name)
#     645                 )
#     646             elif self.if_exists == "replace":
#
# ValueError: Table 'total_deaths' already exists.

# %%
sql_query = '''
    drop materialized view deaths_change_country_date;
    
    create materialized view deaths_change_country_date as (
    with total_deaths_clean as (
        select distinct "Country/Region" as country
        , to_date(level_0, 'M/DD/YY') as date
        , "0" as deaths
        from total_deaths 
    ) 

    -- select * from total_deaths_clean
    select country
    , date
    , deaths
    , lead(deaths) over(partition by country order by date) as yesterdays_deaths
    , lead(deaths) over(partition by country order by date) - deaths as deaths_change
    from total_deaths_clean
    )
    ;
'''
conn.execute(sql_query)
# result not needed here.

# %%
df_sql_death_changes = pd.read_sql('select * from deaths_change_country_date ;', conn)
df_sql_death_changes.head()
# Out:
#        country        date  deaths  yesterdays_deaths  deaths_change
# 0  Afghanistan  2020-01-01       0                4.0            4.0
# 1  Afghanistan  2020-01-01       4                6.0            2.0
# 2  Afghanistan  2020-01-02       6                0.0           -6.0
# 3  Afghanistan  2020-01-02       0                0.0            0.0
# 4  Afghanistan  2020-01-03       0                0.0            0.0

# %%
df_sql_death_changes.to_csv('../data/swl_death_changes.csv')
